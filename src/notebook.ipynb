# %%
from pymongo import MongoClient

import pandas as pd

# Requests sends and recieves HTTP requests.
import requests

# Beautiful Soup parses HTML documents in python.
from bs4 import BeautifulSoup

import json
import time

# %%
# define variables to use for sending requests

# roster_urls = {}
# roster_urls['unc'] = 'https://goheels.com/sports/womens-basketball/roster/'
# roster_urls['duke'] = 'https://goduke.com/sports/womens-basketball/roster/'
# roster_urls['miami'] = 'https://hurricanesports.com/sports/womens-basketball/roster/'
# roster_urls['nc_state'] = 'https://gopack.com/sports/womens-basketball/roster/'

# #List of desired seasons of data - will combine with roster_urls to scrape
# seasons = ['2009-10', '2010-11', '2011-12', '2017-18', '2018-19', '2019-20']

# %%
#Grab requests and input into MongoDB - commented out after completing once
client = MongoClient('localhost', 27017)
db = client.wbb2
rosters = db.rosters

# for season in seasons:
#     for team, url in roster_urls.items():
#         r = requests.get(url + season)
#         rosters.insert_one({'team': team,
#                             'season': season,
#                             'html': r.text})
#         time.sleep(2)

# %% [markdown]
# At this point I have an object (rosters) that contains all the HTML files containing each team's roster for every season.
#
# Now I need to parse the html but make sure to tie it to the correct team & season.
#
# Fields I want are:
# -heights
# -names
# -positions
# -class_yr
#
# Update MongoDB fields to have the keys with the fields you want with values that consist of the parsed out values.
#
# *****Note*****
# -Ran into an issue with parsing the data from Mongo.  I saved the html files in mongo using r.content.  R.content saves the files as bytes rather than strings (r.text).  Didn't find a quick solution to deal with bytes so pulled the html again into the 'wbb2' database and saved it using r.text.
#
# --Update--
# Turns out the CSS classes are different from the first 3 years versus the last 3 (except Duke), so it would of course turn up blank results if I'm searching for the wrong class tag.  This wasn't apparent the first time because I was checking the oldest seasons as opposed to the last seasons.
#
# -Iterate from the end of the cursor and once the lists fail to populate, use a different scheme for parsing.

# %% [markdown]
# Everything here deals with parsing the html using BeautifulSoup and then cleaning the data.

# %%
cursor = rosters.find({})
seasons_2 = ['2017-18', '2018-19', '2019-20']
all_teams = []
for item in cursor:
    if item['season'] in seasons_2 or item['team'] == 'duke':
        soup = BeautifulSoup(item['html'], 'html.parser')
        #run parsing code
        heights = [item.text for item in soup.find_all(class_='height')]
        names = [item.text for item in soup.find_all(class_='sidearm-table-player-name')]
        positions = [item.text for item in soup.find_all(class_='rp_position_short')]
        class_yr = [item.text for item in soup.find_all(class_='roster_class')]
        
        #convert heights of string of ft-inches to an integer of inches
        fix_heights = []
        for height in heights:
            fix_heights.append(12*int(height[0]) + int(height[2:]))
        heights = fix_heights
        
        #code to only keep characters relating to positions
        fixed_pos = []
        for string in positions:
                new_pos = [letter for letter in string if letter.isupper()]
                if len(new_pos) == 1:
                    fixed_pos.append(new_pos[0])
                else:
                    fixed_pos.append(new_pos[0] + "/" + new_pos[1])
        positions = fixed_pos
            
        all_teams.append({'team': item['team'],
                          'season': item['season'],
                          'heights': heights,
                          'names': names,
                          'positions': positions,
                          'class_yr': class_yr})
    else:
        soup = BeautifulSoup(item['html'], 'html.parser')
        #run parsing code
        heights = [item.text for item in soup.find_all(class_='sidearm-roster-player-height')]
        first_names = [item.text for item in soup.find_all(class_='sidearm-roster-player-first-name')]
        last_names = [item.text for item in soup.find_all(class_='sidearm-roster-player-last-name')]
        positions = [item.text for item in soup.find_all(class_='sidearm-list-card-details-item sidearm-roster-player-position-short')]
        class_yr = [item.text for item in soup.find_all(class_='sidearm-roster-player-academic-year')]
        
        #code to get first & last names
        names = [item[0] + ' ' + item[1] for item in zip(first_names, last_names)]
        
        #removes duplicate heights
        heights = heights[:len(names)]
        
        #standardize height format
        heights = [item.replace("'","-") for item in heights]
        heights = [item.replace('"', "") for item in heights]
        
        #convert heights of string of ft-inches to an integer of inches
        fix_heights = []
        for height in heights:
            fix_heights.append(12*int(height[0]) + int(height[2:]))
        heights = fix_heights
        
        #remove duplicate class years
        class_yr = class_yr[-len(names):]
        
        #code to only keep characters relating to positions
        fixed_pos = []
        for string in positions:
                new_pos = [letter for letter in string if letter.isupper()]
                if len(new_pos) == 1:
                    fixed_pos.append(new_pos[0])
                else:
                    fixed_pos.append(new_pos[0] + "/" + new_pos[1])
        positions = fixed_pos
    
        #append desired fields to all_teams list
        all_teams.append({'team': item['team'],
                          'season': item['season'],
                          'heights': heights,
                          'names': names,
                          'positions': positions,
                          'class_yr': class_yr})

# %% [markdown]
# Need to verify all records were correctly pulled by checking for blanks and storing the teams & indices.

# %%
#check for blank teams and the indexes that contain them
blank_teams = []
blank_indices = []
i=0
for item in all_teams:
    if item['heights'] == []:
        blank_teams.append({'team': item['team'],
                            'season': item['season']
        })
        blank_indices.append(i)
        i+=1
    else:
        i+=1

print(blank_indices)
blank_teams
# Out:
# []
# []

# %%
all_teams
# Out:
# [{'team': 'unc',
#   'season': '2009-10',
#   'heights': [73, 65, 70, 71, 70, 77, 72, 66, 74, 78, 73, 76, 70, 68, 75],
#   'names': ['Nyree Williams',
#    "She'la White",
#    'Trinity Bursey',
#    'Candace Wood',
#    'Nicole Powell',
#    'Chay Shegog',
#    'Krista Gross',
#    'Cetera DeGraffenreid',
#    'Martina Wood',
#    'Waltiea Rolle',
#    'Laura Broomfield',
#    'Cierra Robertson-Warren',
#    'Tierra Ruffin-Pratt',
#    'Italee Lucas',
#    'Jessica Breland'],
#   'positions': ['F',
#    'G',
#    'F',
#    'G',
#    'G',
#    'F/C',
#    'G',
#    'G',
#    'F/C',
#    'F/C',
#    'F',
#    'F',
#    'G',
#    'G',
#    'F'],
#   'class_yr': ['Fr.',
#    'So.',
#    'Sr.',
#    'Rs.',
#    'Jr.',
#    'So.',
#    'Fr.',
#    'Jr.',
#    'Sr.',
#    'Fr.',
#    'So.',
#    'Fr.',
#    'Fr.',
#    'Jr.',
#    'Sr.']},
#  {'team': 'duke',
#   'season': '2009-10',
#   'heights': [68, 69, 69, 72, 72, 73, 74, 72, 73, 76, 77],
#   'names': ['Chelsea Hopkins',
#    'Shay Selby',
#    'Jasmine Thomas',
#    'Karima Christmas',
#    'Bridgette Mitchell',
#    'Joy Cheek',
#    'Kathleen Scheer',
#    'Keturah Jackson',
#    'Alexis Rogers',
#    'Krystal Thomas',
#    'Allison Vernerey'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G/F',
#    'F/G',
#    'F',
#    'G/F',
#    'G/F',
#    'G/F',
#    'C',
#    'C'],
#   'class_yr': ['So.',
#    'So.',
#    'Jr.',
#    'Jr.',
#    'Sr.',
#    'Sr.',
#    'So.',
#    'Sr.',
#    'Fr.',
#    'Jr.',
#    'Fr.']},
#  {'team': 'miami',
#   'season': '2009-10',
#   'heights': [67, 68, 76, 71, 63, 73, 74, 74, 71],
#   'names': ['Riquna Williams',
#    'Stefanie Yderstrom',
#    'Hannah Shaw',
#    'Charmaine Clark',
#    'Lee Anna Osei',
#    'Morgan Stroman',
#    'Diane Barnes',
#    'Sylvia Bullock',
#    'Shenise Johnson'],
#   'positions': ['G', 'G', 'C', 'G/F', 'G/F', 'F', 'F', 'F', 'F'],
#   'class_yr': ['So.', 'Fr.', 'Fr.', 'Sr.', 'Fr.', 'Fr.', 'Sr.', 'So.', 'So.']},
#  {'team': 'nc_state',
#   'season': '2009-10',
#   'heights': [66, 69, 65, 75, 68, 77, 75, 71, 69, 73, 69, 76],
#   'names': ['Amber White',
#    'Nikitta Gartrell',
#    'Kim Durham',
#    'Tia Bell',
#    'Emili Tasler',
#    'Inga Muciniece',
#    'Brittany Strachan',
#    'Bonae Holston',
#    'Marisssa Kastanek',
#    'Lucy Ellison',
#    'Sharnise Beal',
#    'Hanna Halteman'],
#   'positions': ['G', 'G', 'G', 'F', 'G', 'C', 'F', 'F', 'G', 'F', 'G', 'C'],
#   'class_yr': ['R-Jr.',
#    'Sr.',
#    'So.',
#    'Jr.',
#    'R-So.',
#    'Sr.',
#    'Jr.',
#    'So.',
#    'Fr.',
#    'Sr.',
#    'Sr.',
#    'R-So.']},
#  {'team': 'unc',
#   'season': '2010-11',
#   'heights': [65, 69, 71, 70, 67, 77, 72, 66, 78, 73, 70, 68, 75],
#   'names': ["She'la White",
#    'Latifah Coleman',
#    'Candace Wood',
#    'Nicole Powell',
#    'Shannon Smith',
#    'Chay Shegog',
#    'Krista Gross',
#    'Cetera DeGraffenreid',
#    'Waltiea Rolle',
#    'Laura Broomfield',
#    'Tierra Ruffin-Pratt',
#    'Italee Lucas',
#    'Jessica Breland'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F/C',
#    'G',
#    'G',
#    'F/C',
#    'F',
#    'G',
#    'G',
#    'F'],
#   'class_yr': ['Jr.',
#    'Fr.',
#    'So.',
#    'Sr.',
#    'Fr.',
#    'Jr.',
#    'So.',
#    'Sr.',
#    'So.',
#    'Jr.',
#    'So.',
#    'Sr.',
#    'Sr.']},
#  {'team': 'duke',
#   'season': '2010-11',
#   'heights': [69, 67, 69, 71, 72, 72, 74, 73, 75, 77, 77],
#   'names': ['Shay Selby',
#    'Chloe Wells',
#    'Jasmine Thomas',
#    'Chelsea Gray',
#    'Karima Christmas',
#    'Richa Jackson',
#    'Kathleen Scheer',
#    'Tricia Liston',
#    'Haley Peters',
#    'Krystal Thomas',
#    'Allison Vernerey'],
#   'positions': ['G', 'G', 'G', 'G', 'G/F', 'F', 'G/F', 'G', 'G/F', 'C', 'C'],
#   'class_yr': ['Jr.',
#    'Fr.',
#    'Sr.',
#    'Fr.',
#    'Sr.',
#    'Fr.',
#    'Jr.',
#    'Fr.',
#    'Fr.',
#    'Sr.',
#    'So.']},
#  {'team': 'miami',
#   'season': '2010-11',
#   'heights': [67, 68, 68, 67, 73, 71, 74, 78, 71, 73, 76, 67],
#   'names': ['Riquna Williams',
#    'Stefanie Yderstrom',
#    'Krystal Saunders',
#    'Stephanie Gardner',
#    'Morgan Stroman',
#    'Suriya McGuire',
#    'Sylvia Bullock',
#    'Shawnice Wilson',
#    'Shenise Johnson',
#    'Maria Brown',
#    'Selina Archer',
#    'Jonathan Teske'],
#   'positions': ['G', 'G', 'G', 'G', 'F', 'G', 'F', 'C', 'G', 'F', 'C'],
#   'class_yr': ['Freshman',
#    'Jr.',
#    'So.',
#    'So.',
#    'Fr.',
#    'So.',
#    'Fr.',
#    'Sr.',
#    'Jr.',
#    'Sr.',
#    'So.',
#    'Fr.']},
#  {'team': 'nc_state',
#   'season': '2010-11',
#   'heights': [66, 66, 65, 75, 71, 70, 68, 75, 71, 69, 76, 62, 76, 74, 76],
#   'names': ['Amber White',
#    'Myisha Goodwin-Coleman',
#    'Kim Durham',
#    'Tia Bell',
#    'Breezy Williams',
#    'Devin Griffin',
#    'Emili Tasler',
#    'Brittany Strachan',
#    'Bonae Holston',
#    'Marissa Kastanek',
#    'Kelsie Lliteras',
#    'Paige Woodard',
#    'Lakeesa Daniel',
#    'Kody Burke',
#    'Hanna Halteman'],
#   'positions': ['G',
#    'G',
#    'G',
#    'F',
#    'F',
#    'G',
#    'G',
#    'F',
#    'F',
#    'G',
#    'F',
#    'G',
#    'F/C',
#    'F',
#    'C'],
#   'class_yr': ['R-Sr.',
#    'Fr.',
#    'Jr.',
#    'Sr.',
#    'Fr.',
#    'Fr.',
#    'R-Jr.',
#    'Sr.',
#    'Jr.',
#    'So.',
#    'So.',
#    'R-Jr.',
#    'R-Fr.',
#    'Fr.',
#    'R-Jr.']},
#  {'team': 'unc',
#   'season': '2011-12',
#   'heights': [65,
#    69,
#    72,
#    71,
#    67,
#    70,
#    69,
#    77,
#    72,
#    74,
#    78,
#    73,
#    70,
#    65,
#    69,
#    72,
#    71,
#    67],
#   'names': ["She'la White",
#    'Latifah Coleman',
#    'Megan Buckland',
#    'Candace Wood',
#    'Shannon Smith',
#    'Danielle Butts',
#    'Brittany Rountree',
#    'Chay Shegog',
#    'Krista Gross',
#    'Whitney Adams',
#    'Waltiea Rolle',
#    'Laura Broomfield',
#    'Tierra Ruffin-Pratt',
#    'Sylvia Hatchell',
#    'Andrew Calder',
#    'Greg Law',
#    'Billy Lee',
#    'Tracey Williams-Johnson'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'C',
#    'G/F',
#    'F',
#    'C',
#    'F',
#    'G'],
#   'class_yr': ['Junior',
#    'Sr.',
#    'Senior',
#    'Jr.',
#    'Junior',
#    'Sr.',
#    'So.',
#    'Fr.',
#    'Jr.',
#    'R-Fr.',
#    'Fr.',
#    'Fr.',
#    'Sr.',
#    'Jr.',
#    'Fr.',
#    'Jr.',
#    'Sr.',
#    'Jr.']},
#  {'team': 'duke',
#   'season': '2011-12',
#   'heights': [75, 69, 67, 71, 70, 72, 74, 76, 73, 75, 66, 77],
#   'names': ['Elizabeth Williams',
#    'Shay Selby',
#    'Chloe Wells',
#    'Chelsea Gray',
#    "Ka'lia Johnson",
#    'Richa Jackson',
#    'Kathleen Scheer',
#    'Amber Henson',
#    'Tricia Liston',
#    'Haley Peters',
#    'Jenna Frush',
#    'Allison Vernerey'],
#   'positions': ['C',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'G/F',
#    'F',
#    'G',
#    'G/F',
#    'G',
#    'C'],
#   'class_yr': ['Fr.',
#    'Sr.',
#    'So.',
#    'So.',
#    'Fr.',
#    'So.',
#    'Sr.',
#    'Fr.',
#    'So.',
#    'So.',
#    'Fr.',
#    'Jr.']},
#  {'team': 'miami',
#   'season': '2011-12',
#   'heights': [67, 68, 68, 68, 67, 73, 71, 74, 78, 71, 73, 76],
#   'names': ['Riquna Williams',
#    'Stefanie Yderstrom',
#    'Michelle Woods',
#    'Krystal Saunders',
#    'Stephanie Gardner',
#    'Morgan Stroman',
#    'Suriya McGuire',
#    'Sylvia Bullock',
#    'Shawnice Wilson',
#    'Shenise Johnson',
#    'Maria Brown',
#    'Selina Archer'],
#   'positions': ['G', 'G', 'G', 'G', 'G', 'F', 'G', 'F', 'C', 'G', 'F', 'C'],
#   'class_yr': ['Sr.',
#    'Jr.',
#    'Fr.',
#    'So.',
#    'So.',
#    'Jr.',
#    'Fr.',
#    'Sr.',
#    'Jr.',
#    'Sr.',
#    'So.',
#    'So.']},
#  {'team': 'nc_state',
#   'season': '2011-12',
#   'heights': [64, 65, 65, 75, 71, 68, 69, 62, 71, 71, 69, 76, 74, 74, 73],
#   'names': ['Myisha Goodwin-Coleman',
#    "Len'Nique Brown",
#    'Kim Durham',
#    'Tia Bell',
#    'Breezy Williams',
#    'Emili Tasler',
#    'Krystal Barrett',
#    'Paige Woodard',
#    'Erica Donovan',
#    'Bonae Holston',
#    'Marissa Kastanek',
#    'Lakeesa Daniel',
#    'Therany Dunnigan',
#    'Kody Burke',
#    'Kiana Evans'],
#   'positions': ['G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'F/C',
#    'F',
#    'F',
#    'F'],
#   'class_yr': ['So.',
#    'So.',
#    'Sr.',
#    'R-Sr.',
#    'So.',
#    'R-Sr.',
#    'Fr.',
#    'R-Sr.',
#    'Fr.',
#    'Sr.',
#    'Jr.',
#    'R-So.',
#    'Fr.',
#    'So.',
#    'Fr.']},
#  {'team': 'unc',
#   'season': '2017-18',
#   'heights': [74, 72, 71, 68, 76, 70, 68, 72, 68, 69, 70, 74, 78, 76],
#   'names': ['Taylor Koenen',
#    'Jocelyn Jones',
#    'Stephanie Watts',
#    'Jamie Cherry',
#    'Emily Sullivan',
#    'Dazia Powell',
#    'Liz Roberts',
#    'Olivia Smith',
#    'Leah Church',
#    'Paris Kea',
#    'Destinee Walker',
#    'Jaelynn Murray',
#    'Naomi Van Nes',
#    'Janelle Bailey'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'C',
#    'C'],
#   'class_yr': ['So.',
#    'R-Fr.',
#    'Jr.',
#    'Sr.',
#    'So.',
#    'Fr.',
#    'So.',
#    'So.',
#    'Fr.',
#    'R-Jr.',
#    'Jr.',
#    'Fr.',
#    'So.',
#    'Fr.']},
#  {'team': 'duke',
#   'season': '2017-18',
#   'heights': [72, 69, 74, 74, 69, 73, 69, 75, 73, 77, 76, 72, 76, 76],
#   'names': ['Haley Gorecki',
#    'Lexie Brown',
#    'Leaonna Odom',
#    'Sofia Roma',
#    'Mikayla Boykin',
#    'Faith Suggs',
#    'Kyra Lambert',
#    'Bego Faz Davalos',
#    'Rebecca Greenwell',
#    'Jade Williams',
#    'Emily Schubert',
#    'Jayda Adams',
#    'Erin Mathias',
#    'Madison Treece'],
#   'positions': ['G',
#    'G',
#    'F',
#    'C',
#    'G',
#    'G/F',
#    'G',
#    'C',
#    'G',
#    'F/C',
#    'C',
#    'G',
#    'F/C',
#    'F'],
#   'class_yr': ['R-So.',
#    'R-Sr.',
#    'So.',
#    'R-Jr.',
#    'Fr.',
#    'Jr.',
#    'Jr.',
#    'R-Sr.',
#    'R-Sr.',
#    'Fr.',
#    'R-Fr.',
#    'Fr.',
#    'Sr.',
#    'Fr.']},
#  {'team': 'miami',
#   'season': '2017-18',
#   'heights': [72, 68, 69, 69, 64, 73, 69, 68, 69, 75, 72, 73, 74, 76, 78],
#   'names': ['Keyanna Harris',
#    'Laura Cornelius',
#    'Endia Banks',
#    'Shaneese Bailey',
#    'Mykea Gray',
#    'Sarah Mortensen',
#    'Taylor Mason',
#    'Neydja Petithomme',
#    'Kelsey Marshall',
#    'Emese Hof',
#    'Rebecca Ripley',
#    'Khaila Prather',
#    'Erykah Davenport',
#    'Beatrice Mompremier',
#    'Serena-Lynn Geldof'],
#   'positions': ['F',
#    'G',
#    'G',
#    'G/F',
#    'G',
#    'G/F',
#    'G',
#    'G',
#    'G',
#    'F/C',
#    'G/F',
#    'F',
#    'F/C',
#    'F',
#    'C'],
#   'class_yr': ['Sr.',
#    'Jr.',
#    'Fr.',
#    'R-Sr.',
#    'Fr.',
#    'So.',
#    'Fr.',
#    'Sr.',
#    'Fr.',
#    'Jr.',
#    'Fr.',
#    'Sr.',
#    'Sr.',
#    'Jr.',
#    'So.']},
#  {'team': 'nc_state',
#   'season': '2017-18',
#   'heights': [69, 68, 68, 74, 72, 73, 69, 74, 73, 77, 66, 75, 70],
#   'names': ['Aislinn Konig',
#    'Kaila  Ealey',
#    'Kai Crutchfield',
#    'Chelsea Nelson',
#    'Kiara  Leslie',
#    'DD Rogers',
#    'Grace Hunter',
#    'Erika  Cassell ',
#    'Kayla Jones',
#    'Akela Maize',
#    'Katie Wadsworth',
#    'Nae Nae Cole',
#    'Armani Hawkins'],
#   'positions': ['G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'F',
#    'G',
#    'F',
#    'F',
#    'C',
#    'G',
#    'C',
#    'G'],
#   'class_yr': ['So.',
#    'R-So.',
#    'Fr.',
#    'Sr.',
#    'R-Jr.',
#    'Jr.',
#    'R-So.',
#    'So.',
#    'Fr.',
#    'Sr.',
#    'So.',
#    'Jr.',
#    'R-Jr.']},
#  {'team': 'unc',
#   'season': '2018-19',
#   'heights': [69,
#    74,
#    67,
#    68,
#    72,
#    71,
#    70,
#    76,
#    72,
#    68,
#    72,
#    68,
#    69,
#    70,
#    74,
#    78,
#    76],
#   'names': ['Shayla Bennett',
#    'Taylor Koenen',
#    'Kennedy Boyd',
#    'Madinah Muhammad',
#    'Jocelyn Jones',
#    'Stephanie Watts',
#    'Claudia Dickey',
#    'Emily Sullivan',
#    'Hunter West',
#    'Liz Roberts',
#    'Olivia Smith',
#    'Leah Church',
#    'Paris Kea',
#    'Destinee Walker',
#    'Jaelynn Murray',
#    'Naomi Van Nes',
#    'Janelle Bailey'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'F',
#    'G',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'C',
#    'C'],
#   'class_yr': ['Jr.',
#    'Jr.',
#    'Fr.',
#    'Sr.',
#    'R-So.',
#    'R-Jr.',
#    'Fr.',
#    'Jr.',
#    'Fr.',
#    'Jr.',
#    'Jr.',
#    'So.',
#    'R-Sr.',
#    'R-Jr.',
#    'So.',
#    'Jr.',
#    'So.']},
#  {'team': 'duke',
#   'season': '2018-19',
#   'heights': [72, 70, 74, 74, 69, 78, 73, 69, 75, 77, 76, 72],
#   'names': ['Haley Gorecki',
#    'Miela Goodchild',
#    'Leaonna Odom',
#    'Sofia Roma',
#    'Mikayla Boykin',
#    'Uchenna Nwoke',
#    'Faith Suggs',
#    'Kyra Lambert',
#    'Onome Akinbode-James',
#    'Jade Williams',
#    'Emily Schubert',
#    'Jayda Adams'],
#   'positions': ['G',
#    'G',
#    'F',
#    'C',
#    'G',
#    'C',
#    'G/F',
#    'G',
#    'F/C',
#    'F/C',
#    'C',
#    'G'],
#   'class_yr': ['R-Jr.',
#    'Fr.',
#    'Jr.',
#    'R-Sr.',
#    'R-Fr.',
#    'Fr.',
#    'Sr.',
#    'R-Jr.',
#    'Fr.',
#    'So.',
#    'R-So.',
#    'So.']},
#  {'team': 'miami',
#   'season': '2018-19',
#   'heights': [68, 69, 70, 64, 73, 69, 72, 69, 75, 72, 73, 76, 72],
#   'names': ['Laura Cornelius',
#    'Endia Banks',
#    'Iggy Allen',
#    'Mykea Gray',
#    'Sarah Mortensen',
#    'Taylor Mason',
#    'Jamir Huston',
#    'Kelsey Marshall',
#    'Emese Hof',
#    'Rebecca Ripley',
#    'Khaila Prather',
#    'Beatrice Mompremier',
#    'Destiny Harden'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'G/F',
#    'G',
#    'F',
#    'G',
#    'F/C',
#    'G/F',
#    'F',
#    'F',
#    'F'],
#   'class_yr': ['R-Jr.',
#    'So.',
#    'R-So.',
#    'So.',
#    'Jr.',
#    'So.',
#    'Fr.',
#    'So.',
#    'Sr.',
#    'R-Fr.',
#    'R-Sr.',
#    'R-Jr.',
#    'So.']},
#  {'team': 'nc_state',
#   'season': '2018-19',
#   'heights': [69, 69, 68, 72, 74, 73, 69, 74, 73, 76, 77, 66, 70],
#   'names': ['Aislinn Konig',
#    'Kaila  Ealey',
#    'Kai Crutchfield',
#    'Kiara  Leslie',
#    'Esra McGoldrick',
#    'DD Rogers',
#    'Grace Hunter',
#    'Erika  Cassell ',
#    'Kayla Jones',
#    'Jada Rice',
#    'Elissa Cunane',
#    'Katie Wadsworth',
#    'Armani Hawkins'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'F',
#    'G',
#    'F',
#    'F',
#    'F',
#    'C',
#    'G',
#    'G'],
#   'class_yr': ['Jr.',
#    'Gr.',
#    'So.',
#    'Gr.',
#    'Fr.',
#    'Sr.',
#    'R-Jr.',
#    'Jr.',
#    'So.',
#    'Fr.',
#    'Fr.',
#    'Jr.',
#    'R-Sr.']},
#  {'team': 'unc',
#   'season': '2019-20',
#   'heights': [74, 68, 70, 70, 76, 68, 72, 68, 75, 69, 76, 70, 71, 78, 74],
#   'names': ['Taylor Koenen',
#    'Madinah Muhammad',
#    'Kennady Tucker',
#    'Claudia Dickey',
#    'Emily Sullivan',
#    'Liz Roberts',
#    'Olivia Smith',
#    'Leah Church',
#    'Malu Tshitenge',
#    'Shayla Bennett',
#    'Janelle Bailey',
#    'Nia Daniel',
#    'Lexi Duckett',
#    'Naomi Van Nes',
#    'Jaelynn Murray'],
#   'positions': ['G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'C',
#    'G',
#    'G',
#    'C',
#    'F'],
#   'class_yr': ['Sr.',
#    'R-Sr.',
#    'Fr.',
#    'So.',
#    'R-Jr.',
#    'Sr.',
#    'Sr.',
#    'Jr.',
#    'Fr.',
#    'Sr.',
#    'Jr.',
#    'Fr.',
#    'Fr.',
#    'Sr.',
#    'Jr.']},
#  {'team': 'duke',
#   'season': '2019-20',
#   'heights': [70, 72, 70, 72, 74, 73, 69, 78, 69, 75, 75, 77, 76, 72],
#   'names': ['Jaida Patrick',
#    'Haley Gorecki',
#    'Miela Goodchild',
#    'Jada Claude',
#    'Leaonna Odom',
#    'Azana Baines',
#    'Mikayla Boykin',
#    'Uchenna Nwoke',
#    'Kyra Lambert',
#    'Jennifer Ezeh',
#    'Onome Akinbode-James',
#    'Jade Williams',
#    'Emily Schubert',
#    'Jayda Adams'],
#   'positions': ['G/F',
#    'G',
#    'G',
#    'G/F',
#    'F',
#    'G',
#    'G',
#    'C',
#    'G',
#    'F',
#    'F/C',
#    'F/C',
#    'C',
#    'G'],
#   'class_yr': ['Fr.',
#    'Gr.',
#    'So.',
#    'Fr.',
#    'Sr.',
#    'Fr.',
#    'R-Fr.',
#    'So.',
#    'Gr.',
#    'Fr.',
#    'So.',
#    'Jr.',
#    'Sr.',
#    'Jr.']},
#  {'team': 'miami',
#   'season': '2019-20',
#   'heights': [69, 72, 72, 69, 64, 70, 69, 72, 69, 75, 69, 76, 75],
#   'names': ['Kenza Salgues',
#    'Moulayna Johnson Sidi Baba',
#    'Destiny Harden',
#    'Endia Banks',
#    'Mykea Gray',
#    'Iggy Allen',
#    'Taylor Mason',
#    'Jamir Huston',
#    'Kelsey Marshall',
#    'Brianna Jackson',
#    'Yasmeen Chang',
#    'Beatrice Mompremier',
#    'Sydnee Roby'],
#   'positions': ['G',
#    'G/F',
#    'F',
#    'G',
#    'G',
#    'G',
#    'G',
#    'F',
#    'G',
#    'F',
#    'G',
#    'F',
#    'C'],
#   'class_yr': ['Fr.',
#    'Fr.',
#    'R-So.',
#    'Jr.',
#    'Jr.',
#    'R-Jr.',
#    'Jr.',
#    'So.',
#    'Jr.',
#    'Fr.',
#    'Fr.',
#    'R-Sr.',
#    'Fr.']},
#  {'team': 'nc_state',
#   'season': '2019-20',
#   'heights': [70, 69, 69, 74, 72, 66, 75, 70, 74, 73, 76, 77, 66, 73],
#   'names': ['Aislinn Konig',
#    'Kaila  Ealey',
#    'Kai Crutchfield',
#    'Jada Boyd',
#    'Jakia Brown-Turner',
#    'Kendal Moore',
#    'Elle Sutphin',
#    'Grace Hunter',
#    'Erika  Cassell ',
#    'Kayla Jones',
#    'Jada Rice',
#    'Elissa Cunane',
#    'Katie Wadsworth',
#    'Camille Hobby'],
#   'positions': ['G',
#    'G',
#    'G',
#    'F',
#    'W',
#    'G',
#    'F',
#    'G',
#    'C',
#    'F',
#    'C',
#    'C',
#    'G',
#    'C'],
#   'class_yr': ['Sr.',
#    'Gr.',
#    'Jr.',
#    'Fr.',
#    'Fr.',
#    'Fr.',
#    'Fr.',
#    'R-Sr.',
#    'Sr.',
#    'Jr.',
#    'So.',
#    'So.',
#    'Sr.',
#    'Fr.']}]

# %% [markdown]
# For my statistical study I'm comparing the average heights of each sample (early years vs. later years).  As a result, I need to have only one instance of any player that played more than one season during that 3 year stretch, otherwise they're being counted multiple times.
#
# In order to do this I'll use sets.

# %%
#Separate all_teams into early_teams & later_teams
early_teams = []
late_teams = []
early_years = ['2009-10', '2010-11', '2011-12']

for dic in all_teams:
    if dic['season'] in early_years:
        early_teams.append(dic)
    else:
        late_teams.append(dic)

#Remove duplicates from early_teams and late_teams
#Pull team, name & height and place in separate lists
early_players = []
late_players = []

# for dic in early_teams:
#     for item in zip(dic['names'], dic['heights']):
#         early_players.append((dic['team'], item[0], item[1]))
        
# for dic in late_teams:
#     for item in zip(dic['names'], dic['heights']):
#         late_players.append((dic['team'], item[0], item[1]))
        
#same process as above but including player positions
for dic in early_teams:
    for item in zip(dic['names'], dic['heights'], dic['positions']):
        early_players.append((dic['team'], item[0], item[1], item[2]))
        
for dic in late_teams:
    for item in zip(dic['names'], dic['heights'], dic['positions']):
        late_players.append((dic['team'], item[0], item[1], item[2]))

#Put items in separated lists in a set to get unique values
early_set = set(early_players)
late_set = set(late_players)

early_set = list(early_set)
late_set = list(late_set)

# %% [markdown]
# -It looks like NC State in particular, re-measured their players after one season and now they have more than one listed height.  I took the larger values of the height... may re-do with smaller values to see what impact it may have.

# %%
# df_early = pd.DataFrame(early_set, columns = ['Team', 'Name', 'Height'])
# df_late = pd.DataFrame(late_set, columns = ['Team', 'Name', 'Height'])

#same process as above but adding player position
df_early = pd.DataFrame(early_set, columns = ['Team', 'Name', 'Height', 'Position'])
df_late = pd.DataFrame(late_set, columns = ['Team', 'Name', 'Height', 'Position'])

# %%
df_early = df_early.sort_values(by=['Name', 'Height'])
df_late = df_late.sort_values(by=['Name', 'Height'])

#Remove duplicates - mainly nc_state players that were measured more than once
#firstlate - kept smaller heights for duplicates
#late - kept larger heights for duplicates
df_early = df_early.drop_duplicates(subset='Name', keep='last')
df_firstlate = df_late.drop_duplicates(subset='Name', keep='first')
df_late = df_late.drop_duplicates(subset='Name', keep='last')

# %%
early_mean = df_early['Height'].mean()
late_mean = df_late['Height'].mean()
print(df_firstlate['Height'].mean())
df_firstlate[df_firstlate['Team'] == 'nc_state']
# Out:
# 71.97727272727273
#         Team                Name  Height Position
# 85  nc_state       Aislinn Konig      69        G
# 38  nc_state         Akela Maize      77        C
# 92  nc_state      Armani Hawkins      70        G
# 6   nc_state       Camille Hobby      73        C
# 12  nc_state      Chelsea Nelson      74        F
# 88  nc_state           DD Rogers      73        F
# 39  nc_state       Elissa Cunane      77        C
# 31  nc_state        Elle Sutphin      75        F
# 18  nc_state     Erika  Cassell       74        C
# 84  nc_state     Esra McGoldrick      74        F
# 68  nc_state        Grace Hunter      69        G
# 15  nc_state           Jada Boyd      74        F
# 5   nc_state           Jada Rice      76        C
# 89  nc_state  Jakia Brown-Turner      72        W
# 71  nc_state     Kai Crutchfield      68        G
# 28  nc_state        Kaila  Ealey      68        G
# 72  nc_state     Katie Wadsworth      66        G
# 78  nc_state         Kayla Jones      73        F
# 76  nc_state        Kendal Moore      66        G
# 29  nc_state       Kiara  Leslie      72        G
# 57  nc_state        Nae Nae Cole      75        C

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

from scipy import stats

fig, ax = plt.subplots(1,2, figsize=(8,5))

df_early.hist(column='Height', bins=10, color='orange' , ax=ax[0])
df_late.hist(column='Height', bins=10, color='red', alpha=0.5, ax=ax[1])

ax[0].set_title('2009-12 Players', fontsize=14)
ax[0].set_xlabel('Height', fontsize=14)
ax[0].set_ylabel('Count', fontsize=14)
ax[0].axvline(early_mean, color='black', label='Sample Mean')
ax[0].legend()

ax[1].set_title('2017-20 Players', fontsize=14)
ax[1].set_xlabel('Height', fontsize=14)
ax[1].set_ylabel('Count', fontsize=14)
ax[1].axvline(late_mean, color='black', label='Sample Mean')
ax[1].legend()

#Create same bin widths for both groups

fig.tight_layout()

# %% [markdown]
# Histograms show multi-modal distributions.  Since the z-test is based on the normal distribution, the t-test will be a more appropriate test to use.
#
# Key Differences Between T-test and Z-test
# The difference between t-test and z-test can be drawn clearly on the following grounds:
#
# 1 - The t-test can be understood as a statistical test which is used to compare and analyse whether the means of the two population is different from one another or not when the standard deviation is not known. As against, Z-test is a parametric test, which is applied when the standard deviation is known, to determine, if the means of the two datasets differ from each other.
#
# 2 - The t-test is based on Student’s t-distribution. On the contrary, z-test relies on the assumption that the distribution of sample means is normal. Both student’s t-distribution and normal distribution appear alike, as both are symmetrical and bell-shaped. However, they differ in the sense that in a t-distribution, there is less space in the centre and more in the tails.
#
# 3 - One of the important conditions for adopting t-test is that population variance is unknown. Conversely, population variance should be known or assumed to be known in case of a z-test.
#
# 4 - Z-test is used to when the sample size is large, i.e. n > 30, and t-test is appropriate when the size of the sample is small, in the sense that n < 30.

# %% [markdown]
# Steps:
#
# 1 - Hypotheses
#
# Null - The average height of players from 2017-2020 is equal to the average height of players from 2009-2012.
#
# Alternate - The average height of players from 2017-2020 is not equal to the average height of players from 2009-2012.
#
# 2 - Confidence Interval (alpha)
# Default choice of alpha = 0.05 (95% confidence level)
#
# 3 - Data sets
# df_early['Height']
# df_late['Height']

# %%
#Conduct t-test
stat, p_val = stats.ttest_ind(df_late['Height'], df_early['Height'], equal_var='False')
print('The statistic is: {} \nP-value: {}'.format(stat ,p_val))
# Out:
# The statistic is: 1.3736990917674263
# P-value: 0.17136534877746223

# %% [markdown]
# The P-value is > 0.05, so the null hypothesis can not be rejected. The two samples are equal to one another.

# %%
df_late['Position'].unique()
# Out:
# array(['G', 'C', 'F', 'F/C', 'G/F', 'W'], dtype=object)

# %%
df_late['Position'] = df_late['Position'].map({'G':'G', 'C':'C', 'F':'F', 'F/C':'F/C', 'G/F':'G/F', 'W':'F'})

# %%
df_early['Position'] = df_early['Position'].map({'G/F':'G/F', 'C':'C', 'F':'F', 'G':'G', 'F/G':'G/F', 'F/C':'F/C' })

# %%
df_early['Position'].unique()
# Out:
# array(['G/F', 'C', 'F', 'G', 'F/C'], dtype=object)

# %%
guards = ['G', 'G/F']
forwards = ['F', 'F/C']
centers = ['C']

df_early_guards = df_early[df_early['Position'].isin(guards)]
df_early_forwards = df_early[df_early['Position'].isin(forwards)]
df_early_centers = df_early[df_early['Position'].isin(centers)]

df_late_guards = df_late[df_late['Position'].isin(guards)]
df_late_forwards = df_late[df_late['Position'].isin(forwards)]
df_late_centers = df_late[df_late['Position'].isin(centers)]

# %%
df_late_centers['Position'].unique()
# Out:
# array(['C'], dtype=object)

# %%
fig, axs = plt.subplots(3, 2, figsize=(8,5))

ax1 = axs[0, 0]
ax2 = axs[0, 1]
ax3 = axs[1, 0]
ax4 = axs[1, 1]
ax5 = axs[2,0]
ax6 = axs[2,1]

df_early_guards.hist(column='Height', bins=10, color='blue', ax=ax1)
df_late_guards.hist(column='Height', bins=10, color='green', ax=ax2)

df_early_forwards.hist(column='Height', bins=10, color='blue', ax=ax3)
df_late_forwards.hist(column='Height', bins=10, color='green', ax=ax4)

df_early_centers.hist(column='Height', bins=10, color='blue', ax=ax5)
df_late_centers.hist(column='Height', bins=10, color='green', ax=ax6)

ax1.set_title('2009-12 Guards', fontsize=10)
ax1.set_xlabel('Height', fontsize=12)
ax1.set_ylabel('Count', fontsize=12)
ax1.axvline(df_early_guards['Height'].mean(), color='black', label='Sample Mean')
ax1.legend()

ax2.set_title('2017-20 Guards', fontsize=10)
ax2.set_xlabel('Height', fontsize=12)
ax2.set_ylabel('Count', fontsize=12)
ax2.axvline(df_late_guards['Height'].mean(), color='black', label='Sample Mean')
ax2.legend()

ax3.set_title('2009-12 Forwards', fontsize=10)
ax3.set_xlabel('Height', fontsize=12)
ax3.set_ylabel('Count', fontsize=12)
ax3.axvline(df_early_forwards['Height'].mean(), color='black', label='Sample Mean')
ax3.legend()

ax4.set_title('2017-20 Forwards', fontsize=10)
ax4.set_xlabel('Height', fontsize=12)
ax4.set_ylabel('Count', fontsize=12)
ax4.axvline(df_late_forwards['Height'].mean(), color='black', label='Sample Mean')
ax4.legend()

ax5.set_title('2009-12 Centers', fontsize=10)
ax5.set_xlabel('Height', fontsize=12)
ax5.set_ylabel('Count', fontsize=12)
ax5.axvline(df_early_centers['Height'].mean(), color='black', label='Sample Mean')
ax5.legend()

ax6.set_title('2017-20 Centers', fontsize=10)
ax6.set_xlabel('Height', fontsize=12)
ax6.set_ylabel('Count', fontsize=12)
ax6.axvline(df_late_centers['Height'].mean(), color='black', label='Sample Mean')
ax6.legend()

fig.tight_layout()

stat, p_val = stats.ttest_ind(df_early_guards['Height'], df_late_guards['Height'])
print('Guards:\nThe statistic is: {} \nP-value: {}'.format(stat ,p_val))

stat, p_val = stats.ttest_ind(df_early_forwards['Height'], df_late_forwards['Height'])
print('Forwards:\nThe statistic is: {} \nP-value: {}'.format(stat ,p_val))

stat, p_val = stats.ttest_ind(df_early_centers['Height'], df_late_centers['Height'])
print('Centers:\nThe statistic is: {} \nP-value: {}'.format(stat ,p_val))
# Out:
# Guards:
# The statistic is: -1.776222969496628
# P-value: 0.07893177552181647
# Forwards:
# The statistic is: -1.1801162957398803
# P-value: 0.24342920766523984
# Centers:
# The statistic is: 1.0690449676497051
# P-value: 0.29844377157082497
